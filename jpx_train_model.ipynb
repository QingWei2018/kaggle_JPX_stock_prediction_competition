# %% [markdown]
# # imports

# %%
import math
import os
from scipy import stats
import lightgbm as lgb
import pandas as pd
import numpy as np
import warnings
import random

warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)

# %% [markdown]
# # data loading and preprocessing

# %%
financials1=pd.read_csv(r"G:\.shortcut-targets-by-id\1VYwE_M93mefT96L13j17FvaBdNSNnykZ\Kaggle\jpx-tokyo-stock-exchange-prediction\train_files\financials.csv")
financials2=pd.read_csv(r"G:\.shortcut-targets-by-id\1VYwE_M93mefT96L13j17FvaBdNSNnykZ\Kaggle\jpx-tokyo-stock-exchange-prediction\supplemental_files\financials.csv")
stock_prices1=pd.read_csv(r"G:\.shortcut-targets-by-id\1VYwE_M93mefT96L13j17FvaBdNSNnykZ\Kaggle\jpx-tokyo-stock-exchange-prediction\train_files\stock_prices.csv")
stock_prices2=pd.read_csv(r"G:\.shortcut-targets-by-id\1VYwE_M93mefT96L13j17FvaBdNSNnykZ\Kaggle\jpx-tokyo-stock-exchange-prediction\supplemental_files\stock_prices.csv")


stock_info=pd.read_csv(r"G:\.shortcut-targets-by-id\1VYwE_M93mefT96L13j17FvaBdNSNnykZ\Kaggle\jpx-tokyo-stock-exchange-prediction\stock_list.csv")

# %%
financials=pd.concat([financials1,financials2])
stock_prices=pd.concat([stock_prices1,stock_prices2])

# %%
def proprocessing_financials(financials):
    def finance_check(x):
        if "_Consolidated_" in x:
            return 1
        else:
            return 0
    
    
    financials["TypeOfDocument"]=financials["TypeOfDocument"].astype(str)
    financials["OperatingProfit"]=financials["OperatingProfit"].apply(convert_float)
    financials["NetSales"]=financials["NetSales"].apply(convert_float)
    financials['EquityToAssetRatio']= financials['EquityToAssetRatio'].apply(convert_float)
    
    
    financials["check"]=financials["TypeOfDocument"].apply(lambda x: 1 if "_Consolidated_" in x else 0)
    financials=financials[financials["check"]==1]
    financials=financials.fillna(0)
    financials=financials.replace([np.inf, -np.inf], 0)
    financials["OperationMargin"] = financials["OperatingProfit"]/financials["NetSales"]
    financials=financials.replace([np.inf, -np.inf], 0)
    financials["Statement_Date"]=1
   
    
    return financials[['Date', 'SecuritiesCode','OperationMargin','EquityToAssetRatio','Statement_Date']]

# %%
def convert_float(x):
    try:
        return float(x)
    except:
        return None
    
def seq_count(row):
    if pd.isna(row["close4"]):
        return None
    elif row["4_day_compare"]==0:
        return row["count"]*(-1)
    else:
        return row["count"]
    
def convert_str(x):
    try:
        return str(x)
    except:
        return None

# %%
def stock_info_preprocessing(stock_info):

    #keep 33 sector code to capture difference in industries, and issued shares in order to calculate daily transaction ration
    
    return stock_info[["SecuritiesCode","33SectorCode","IssuedShares"]]

# %%
def real_close(prices):
    prices=prices.sort_values("Date", ascending=False)
    prices["CumAdjustFactor"] = prices["AdjustmentFactor"].cumprod()
    prices["real_close"] = prices["CumAdjustFactor"]*prices["Close"]
    prices= prices.sort_values("Date")
    prices[prices["real_close"]==0]["real_close"] = np.nan
    prices["real_close"] = prices["real_close"].ffill()
    return prices

# %%
def price_preprocess(prices):
    prices.fillna(0)
    prices.replace([np.inf, -np.inf], 0)
    prices = prices.sort_values(["SecuritiesCode", "Date"])
    
    prices['volume_ratio']=prices["Volume"]/prices["IssuedShares"]  # transaction ratio
    prices['daily_price_change']=(prices["High"]-prices["Low"])/prices["Open"]  # the price voltaility  over a day
    prices["price/volume"]=prices["daily_price_change"]/prices["volume_ratio"] #  
    
    df=pd.DataFrame()
    stock_code_list=prices.SecuritiesCode.unique().tolist()
    


    
    for codei in stock_code_list:

        stocki_df=prices[prices["SecuritiesCode"]==codei]
        
     
        #daily price change AR(n)s
        stocki_df["daily_price_change1"]=stocki_df["daily_price_change"].shift(1)
        stocki_df["daily_price_change2"]=stocki_df["daily_price_change"].shift(2)
        stocki_df["daily_price_change3"]=stocki_df["daily_price_change"].shift(3)
        stocki_df["daily_price_change4"]=stocki_df["daily_price_change"].shift(4)
        
        
        # if a stock has a sequencial gain or loss compares with 4 days ago
        stocki_df["close4"]=stocki_df["real_close"].shift(4)
        stocki_df["4_day_compare"]=(stocki_df["real_close"]>=stocki_df["close4"]).astype(int)
        groups = (stocki_df['4_day_compare'] != stocki_df['4_day_compare'].shift()).cumsum()
        stocki_df["count"]=stocki_df.groupby(["4_day_compare",groups]).cumcount()+1
        stocki_df["seq_count"]=stocki_df.apply(seq_count,axis=1)

        #brein band 
        stocki_df["brein_up"] = stocki_df['real_close'].rolling(window=20).mean() +2*stocki_df['real_close'].rolling(window=20).std()

        stocki_df["brein_down"] = stocki_df['real_close'].rolling(window=20).mean() -2*stocki_df['real_close'].rolling(window=20).std()
        stocki_df["brein_width"] = stocki_df['real_close'].rolling(window=20).mean() +4*stocki_df['real_close'].rolling(window=20).std()
        #stocki_df["distance_brein_up"] = np.abs(stocki_df['real_close'] -stocki_df["brein_up"]) / stocki_df["brein_width"]
        #stocki_df["distance_brein_down"] = np.abs(stocki_df['real_close'] -stocki_df["brein_down"]) / stocki_df["brein_width"]


        # RSI -14days

        stocki_df["real_close_diff1"]=stocki_df["real_close"].diff(1)
        stocki_df["gain"]=stocki_df["real_close_diff1"].clip(lower=0)
        stocki_df["loss"]=stocki_df["real_close_diff1"].clip(upper=0).abs()
        stocki_df["avg_gain"]=stocki_df["gain"].rolling(window=14).mean()
        stocki_df["avg_loss"]=stocki_df["loss"].rolling(window=14).mean()
        #stocki_df["RS"]=stocki_df["avg_gain"]/stocki_df["avg_loss"]
        #stocki_df["RSI"]= 100-(100/(1+stocki_df["RS"]))
       



        

        #targets ARs

        stocki_df["future_close1"]=stocki_df["real_close"].shift(-1)
        stocki_df["future_close2"]=stocki_df["real_close"].shift(-2)
        stocki_df["calculated_target"]=(stocki_df["future_close2"] - stocki_df["future_close1"])/stocki_df["future_close1"]
        stocki_df["target_3"]=stocki_df["calculated_target"].shift(3)
        stocki_df["target_4"]=stocki_df["calculated_target"].shift(4)
        stocki_df["target_5"]=stocki_df["calculated_target"].shift(5)

     
        
        #price moving average ratio
        stocki_df['5_day_price_MA_ratio']  = stocki_df['real_close']/stocki_df['real_close'].rolling(window=5).mean()
        stocki_df['10_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=10).mean()
        stocki_df['20_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=20).mean()
        stocki_df['40_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=40).mean()
        stocki_df['60_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=60).mean()
        stocki_df['120_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=120).mean()
        
        
        # price volatilities
        #stocki_df['5_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=5).std()
        #stocki_df['10_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=10).std()
        stocki_df['20_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=20).std()
        stocki_df['40_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=40).std()
        stocki_df['60_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=60).std()
        stocki_df['120_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=120).std()
        
        # return AR(n)s
        
        stocki_df["5_day_return"]=stocki_df["real_close"].pct_change(5)
        stocki_df["10_day_return"]=stocki_df["real_close"].pct_change(10)
        stocki_df["20_day_return"]=stocki_df["real_close"].pct_change(20)
        stocki_df["40_day_return"]=stocki_df["real_close"].pct_change(40)
        stocki_df["60_day_return"]=stocki_df["real_close"].pct_change(60)
        stocki_df["120_day_return"]=stocki_df["real_close"].pct_change(120)
     
       # volume moving average
        
        
        stocki_df["5_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=5).mean()
        stocki_df["10_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=10).mean()
        stocki_df["20_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=20).mean()
        stocki_df["40_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=40).mean()
      
       # volumn volatilities
        
        #stocki_df["5_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=5).std()
        #stocki_df["10_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=10).std()
        stocki_df["20_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=20).std()
        stocki_df["40_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=40).std()
        stocki_df["60_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=60).std()
        stocki_df["120_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=120).std()

       #
        
        

        df=pd.concat([df,stocki_df]) 

    df["distance_brein_up"] = round(np.abs(df['real_close'] -df["brein_up"]) / df["brein_width"],2)
    df["distance_brein_down"] = round(np.abs(df['real_close'] - df["brein_down"]) / df["brein_width"],2)

    df["RS"]=round(df["avg_gain"]/df["avg_loss"],2)
    df["RSI"]= round(100-(100/(1+df["RS"])),0)

        
    return df

# %%
def train_data_preprocess(stock_prices,stock_info,financials):
    stock_info=stock_info_preprocessing(stock_info)
    finance=proprocessing_financials(financials)
    prices=stock_prices.merge(stock_info,left_on=["SecuritiesCode"],right_on=["SecuritiesCode"],how="left")
    prices = prices.sort_values(["SecuritiesCode", "Date"])
    prices = prices.groupby("SecuritiesCode").apply(real_close).reset_index(drop=True)
    prices=price_preprocess(prices)
    prices=prices.merge(finance,left_on=["Date","SecuritiesCode"],right_on=["Date","SecuritiesCode"],how="left")
    prices['OperationMargin']=prices['OperationMargin'].fillna(method="ffill")
    prices['EquityToAssetRatio']=prices['EquityToAssetRatio'].fillna(method="ffill")
    prices["Volume"]=prices["Volume"].astype(float)
    prices["33SectorCode"]= prices["33SectorCode"].astype(int)
    prices["SupervisionFlag"]= prices["SupervisionFlag"].astype(int)
    
    return prices

# %%
data=train_data_preprocess(stock_prices,stock_info,financials)

# %%
#customized lightgmb loss funtion

def l2_loss(y, data):
    t = data.get_label()
    grad = y - t 
    hess = np.ones_like(y)
    return grad, hess

def l2_eval(y, data):
    t = data.get_label()
    loss = (y - t) ** 2 
    return 'l2', loss.mean(), False  

def feval_pearsonr(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'pearsonr', stats.pearsonr(y_true, y_pred)[0], True

# %% [markdown]
# # hyperpara tuning

# %%
from hyperopt import hp, fmin, tpe, Trials, partial
from hyperopt.early_stop import no_progress_loss
import os

# %%
def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

SEED=42
seed_everything(SEED)

# %%
# use sharpe ratio for hyperparameter tuning
def calc_spread_return_per_day(df, portfolio_size=200, toprank_weight_ratio=2):
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def sharpe_ratio(preds,test):
    weights=np.linspace(2,1,200)
    temp_pred=test[['Date','SecuritiesCode','Target']].copy()
    temp_pred["PTarget"]=preds
    temp_pred["Rank"]=temp_pred.groupby(["Date"])["PTarget"].rank(ascending=False, method="first") - 1
    temp_pred["Rank"]=temp_pred["Rank"].astype(int)
    buf=temp_pred.groupby('Date').apply(calc_spread_return_per_day,portfolio_size=200, toprank_weight_ratio=2)
   
    return -buf.mean()/buf.std()

# %%
data["Date"].min(), data["Date"].max()
# Out:
# ('2017-01-04', '2022-06-24')

# %%
#train validation split, randomly select 1400 stocks for training, 600 stocks for validating
code_list=data.SecuritiesCode.unique().tolist()
train_list=random.sample(code_list,1400)
validation_list=np.setxor1d(code_list,train_list)

# %%
train=data[data['SecuritiesCode'].isin(train_list)]
test=data[data['SecuritiesCode'].isin(validation_list)]

# %%
# define features and datasets

features=[ 'ExpectedDividend', 'Volume',"daily_price_change","daily_price_change1",
          "daily_price_change2","daily_price_change3","daily_price_change4",
          '33SectorCode','OperationMargin','EquityToAssetRatio','volume_ratio',"distance_brein_up","distance_brein_down","RSI",
          'seq_count','target_3','target_4','target_5',"SupervisionFlag",
          '5_day_price_MA_ratio',
          '10_day_price_MA_ratio', '20_day_price_MA_ratio',
          '40_day_price_MA_ratio', '60_day_price_MA_ratio',
          '120_day_price_MA_ratio', 
               
               '20_day_price_volatility','40_day_price_volatility',
               '60_day_price_volatility', '120_day_price_volatility',
                '5_day_return', '10_day_return',
               '20_day_return', '40_day_return', '60_day_return', '120_day_return',
               "5_day_volume_ratio_MA","10_day_volume_ratio_MA","20_day_volume_ratio_MA","40_day_volume_ratio_MA",
                '20_day_volume_ratio_std','40_day_volume_ratio_std',
               '60_day_volume_ratio_std', '120_day_volume_ratio_std',"price/volume"
               ]

tr_dataset = lgb.Dataset(train[features],train["Target"],feature_name = features,categorical_feature=['33SectorCode'],free_raw_data=False )

# %%
# define tuning object, minimize -sharpe ration
def object(params):

    params_lgb={'metric':'None',
            'objective': 'regression',
            'force_col_wise':True,
            'learning_rate': params["learning_rate"],
            'num_leaves': params["num_leaves"],
            'min_data_in_leaf':params['min_data_in_leaf'],
            #'max_depth': params["max_depth"],
            'subsample': params["subsample"],
            'feature_fraction': params['feature_fraction'],
            'bagging_fraction': params['bagging_fraction'],
            'lambda_l1': params['lambda_l1'],
            'lambda_l2': params['lambda_l2'],
          
            }  

    

    model = lgb.train(  params = params_lgb, 
                train_set = tr_dataset,                
                num_boost_round = 500, 
                feval=feval_pearsonr
               )
    
    preds=model.predict(test[features])

    return sharpe_ratio(preds,test)


# define parameter seach space

space = {
    'num_leaves':  hp.choice('num_leaves', range(50,100)),
    'min_data_in_leaf':  hp.choice('min_data_in_leaf', range(100,500)),
    'max_depth':  hp.choice('max_depth', range(3,10)),
    'feature_fraction':  hp.uniform('feature_fraction', 0.2, 0.9),
    'subsample':  hp.uniform('subsample', 0.5, 0.9),
    'bagging_fraction':  hp.uniform('bagging_fraction', 0.5, 0.9),    
    'learning_rate':  hp.uniform('learning_rate', 0.001, 0.1),
    'lambda_l1':  hp.uniform('lambda_l1', 0.0001, 1),
    'lambda_l2':  hp.uniform('lambda_l2', 0.0001, 1),
    
}

# %%
# define tuning process
def param_hyperopt(max_evals,space):

    trials=Trials()

    early_stop_fn= no_progress_loss(200)

    params_best= fmin(object, space=space,algo=tpe.suggest, max_evals=max_evals,verbose=True,trials=trials,early_stop_fn=early_stop_fn)

    print("best params:", params_best)

    return params_best,trials

# %%
# start tuning
params_best,trails=param_hyperopt(3000,space)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8339998276500189, subsample=0.7078259526546407 will be ignored. Current value: bagging_fraction=0.8339998276500189
# [LightGBM] [Warning] bagging_fraction is set=0.8339998276500189, subsample=0.7078259526546407 will be ignored. Current value: bagging_fraction=0.8339998276500189
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5047940138092927, subsample=0.7484116090329118 will be ignored. Current value: bagging_fraction=0.5047940138092927
# [LightGBM] [Warning] bagging_fraction is set=0.5047940138092927, subsample=0.7484116090329118 will be ignored. Current value: bagging_fraction=0.5047940138092927
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.886199340919434, subsample=0.7142096388562116 will be ignored. Current value: bagging_fraction=0.886199340919434
# [LightGBM] [Warning] bagging_fraction is set=0.886199340919434, subsample=0.7142096388562116 will be ignored. Current value: bagging_fraction=0.886199340919434
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6173027086370216, subsample=0.8205105553118759 will be ignored. Current value: bagging_fraction=0.6173027086370216
# [LightGBM] [Warning] bagging_fraction is set=0.6173027086370216, subsample=0.8205105553118759 will be ignored. Current value: bagging_fraction=0.6173027086370216
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8285554957708399, subsample=0.8709028183995708 will be ignored. Current value: bagging_fraction=0.8285554957708399
# [LightGBM] [Warning] bagging_fraction is set=0.8285554957708399, subsample=0.8709028183995708 will be ignored. Current value: bagging_fraction=0.8285554957708399
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6173403502048364, subsample=0.8816910577175414 will be ignored. Current value: bagging_fraction=0.6173403502048364
# [LightGBM] [Warning] bagging_fraction is set=0.6173403502048364, subsample=0.8816910577175414 will be ignored. Current value: bagging_fraction=0.6173403502048364
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8857864227989589, subsample=0.8165377165501662 will be ignored. Current value: bagging_fraction=0.8857864227989589
# [LightGBM] [Warning] bagging_fraction is set=0.8857864227989589, subsample=0.8165377165501662 will be ignored. Current value: bagging_fraction=0.8857864227989589
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6972137558926317, subsample=0.655494412652306 will be ignored. Current value: bagging_fraction=0.6972137558926317
# [LightGBM] [Warning] bagging_fraction is set=0.6972137558926317, subsample=0.655494412652306 will be ignored. Current value: bagging_fraction=0.6972137558926317
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5567792650231537, subsample=0.5870467884552759 will be ignored. Current value: bagging_fraction=0.5567792650231537
# [LightGBM] [Warning] bagging_fraction is set=0.5567792650231537, subsample=0.5870467884552759 will be ignored. Current value: bagging_fraction=0.5567792650231537
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5821414269648826, subsample=0.8112751264913629 will be ignored. Current value: bagging_fraction=0.5821414269648826
# [LightGBM] [Warning] bagging_fraction is set=0.5821414269648826, subsample=0.8112751264913629 will be ignored. Current value: bagging_fraction=0.5821414269648826
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7610680790609933, subsample=0.8154066654727959 will be ignored. Current value: bagging_fraction=0.7610680790609933
# [LightGBM] [Warning] bagging_fraction is set=0.7610680790609933, subsample=0.8154066654727959 will be ignored. Current value: bagging_fraction=0.7610680790609933
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6876507539251394, subsample=0.777605121247879 will be ignored. Current value: bagging_fraction=0.6876507539251394
# [LightGBM] [Warning] bagging_fraction is set=0.6876507539251394, subsample=0.777605121247879 will be ignored. Current value: bagging_fraction=0.6876507539251394
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8915011785851499, subsample=0.6783279062142695 will be ignored. Current value: bagging_fraction=0.8915011785851499
# [LightGBM] [Warning] bagging_fraction is set=0.8915011785851499, subsample=0.6783279062142695 will be ignored. Current value: bagging_fraction=0.8915011785851499
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6846340518400094, subsample=0.8706608134376157 will be ignored. Current value: bagging_fraction=0.6846340518400094
# [LightGBM] [Warning] bagging_fraction is set=0.6846340518400094, subsample=0.8706608134376157 will be ignored. Current value: bagging_fraction=0.6846340518400094
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8162174148664565, subsample=0.6743570446385785 will be ignored. Current value: bagging_fraction=0.8162174148664565
# [LightGBM] [Warning] bagging_fraction is set=0.8162174148664565, subsample=0.6743570446385785 will be ignored. Current value: bagging_fraction=0.8162174148664565
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7950296169147364, subsample=0.8459679366698272 will be ignored. Current value: bagging_fraction=0.7950296169147364
# [LightGBM] [Warning] bagging_fraction is set=0.7950296169147364, subsample=0.8459679366698272 will be ignored. Current value: bagging_fraction=0.7950296169147364
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5140450915594117, subsample=0.6579143462315402 will be ignored. Current value: bagging_fraction=0.5140450915594117
# [LightGBM] [Warning] bagging_fraction is set=0.5140450915594117, subsample=0.6579143462315402 will be ignored. Current value: bagging_fraction=0.5140450915594117
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.880356078463554, subsample=0.5143674601312451 will be ignored. Current value: bagging_fraction=0.880356078463554
# [LightGBM] [Warning] bagging_fraction is set=0.880356078463554, subsample=0.5143674601312451 will be ignored. Current value: bagging_fraction=0.880356078463554
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8982912570547732, subsample=0.7899727784278296 will be ignored. Current value: bagging_fraction=0.8982912570547732
# [LightGBM] [Warning] bagging_fraction is set=0.8982912570547732, subsample=0.7899727784278296 will be ignored. Current value: bagging_fraction=0.8982912570547732
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7510267795599451, subsample=0.8985452731924788 will be ignored. Current value: bagging_fraction=0.7510267795599451
# [LightGBM] [Warning] bagging_fraction is set=0.7510267795599451, subsample=0.8985452731924788 will be ignored. Current value: bagging_fraction=0.7510267795599451
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6372563858168727, subsample=0.8826343466139456 will be ignored. Current value: bagging_fraction=0.6372563858168727
# [LightGBM] [Warning] bagging_fraction is set=0.6372563858168727, subsample=0.8826343466139456 will be ignored. Current value: bagging_fraction=0.6372563858168727
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7440990441489044, subsample=0.8454518360167306 will be ignored. Current value: bagging_fraction=0.7440990441489044
# [LightGBM] [Warning] bagging_fraction is set=0.7440990441489044, subsample=0.8454518360167306 will be ignored. Current value: bagging_fraction=0.7440990441489044
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6452287509256033, subsample=0.5953917006949301 will be ignored. Current value: bagging_fraction=0.6452287509256033
# [LightGBM] [Warning] bagging_fraction is set=0.6452287509256033, subsample=0.5953917006949301 will be ignored. Current value: bagging_fraction=0.6452287509256033
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6430407165077549, subsample=0.603589997754684 will be ignored. Current value: bagging_fraction=0.6430407165077549
# [LightGBM] [Warning] bagging_fraction is set=0.6430407165077549, subsample=0.603589997754684 will be ignored. Current value: bagging_fraction=0.6430407165077549
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.612351446068696, subsample=0.5163377750557351 will be ignored. Current value: bagging_fraction=0.612351446068696
# [LightGBM] [Warning] bagging_fraction is set=0.612351446068696, subsample=0.5163377750557351 will be ignored. Current value: bagging_fraction=0.612351446068696
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6586692478238143, subsample=0.5142231405324279 will be ignored. Current value: bagging_fraction=0.6586692478238143
# [LightGBM] [Warning] bagging_fraction is set=0.6586692478238143, subsample=0.5142231405324279 will be ignored. Current value: bagging_fraction=0.6586692478238143
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6609974131999272, subsample=0.5492590642577162 will be ignored. Current value: bagging_fraction=0.6609974131999272
# [LightGBM] [Warning] bagging_fraction is set=0.6609974131999272, subsample=0.5492590642577162 will be ignored. Current value: bagging_fraction=0.6609974131999272
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5508901001962261, subsample=0.6143637930082633 will be ignored. Current value: bagging_fraction=0.5508901001962261
# [LightGBM] [Warning] bagging_fraction is set=0.5508901001962261, subsample=0.6143637930082633 will be ignored. Current value: bagging_fraction=0.5508901001962261
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7249605546169235, subsample=0.5495984143814363 will be ignored. Current value: bagging_fraction=0.7249605546169235
# [LightGBM] [Warning] bagging_fraction is set=0.7249605546169235, subsample=0.5495984143814363 will be ignored. Current value: bagging_fraction=0.7249605546169235
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7188375263560621, subsample=0.5484677383116058 will be ignored. Current value: bagging_fraction=0.7188375263560621
# [LightGBM] [Warning] bagging_fraction is set=0.7188375263560621, subsample=0.5484677383116058 will be ignored. Current value: bagging_fraction=0.7188375263560621
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5860385901483323, subsample=0.6085990892832979 will be ignored. Current value: bagging_fraction=0.5860385901483323
# [LightGBM] [Warning] bagging_fraction is set=0.5860385901483323, subsample=0.6085990892832979 will be ignored. Current value: bagging_fraction=0.5860385901483323
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.652965088299399, subsample=0.5719382621247575 will be ignored. Current value: bagging_fraction=0.652965088299399
# [LightGBM] [Warning] bagging_fraction is set=0.652965088299399, subsample=0.5719382621247575 will be ignored. Current value: bagging_fraction=0.652965088299399
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5158459496478237, subsample=0.6276894902753603 will be ignored. Current value: bagging_fraction=0.5158459496478237
# [LightGBM] [Warning] bagging_fraction is set=0.5158459496478237, subsample=0.6276894902753603 will be ignored. Current value: bagging_fraction=0.5158459496478237
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6701486315606945, subsample=0.7270888714159662 will be ignored. Current value: bagging_fraction=0.6701486315606945
# [LightGBM] [Warning] bagging_fraction is set=0.6701486315606945, subsample=0.7270888714159662 will be ignored. Current value: bagging_fraction=0.6701486315606945
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7815977712666433, subsample=0.5056200600869363 will be ignored. Current value: bagging_fraction=0.7815977712666433
# [LightGBM] [Warning] bagging_fraction is set=0.7815977712666433, subsample=0.5056200600869363 will be ignored. Current value: bagging_fraction=0.7815977712666433
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5411768825591312, subsample=0.63448669548647 will be ignored. Current value: bagging_fraction=0.5411768825591312
# [LightGBM] [Warning] bagging_fraction is set=0.5411768825591312, subsample=0.63448669548647 will be ignored. Current value: bagging_fraction=0.5411768825591312
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6050102564980777, subsample=0.5343383047725833 will be ignored. Current value: bagging_fraction=0.6050102564980777
# [LightGBM] [Warning] bagging_fraction is set=0.6050102564980777, subsample=0.5343383047725833 will be ignored. Current value: bagging_fraction=0.6050102564980777
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.8554539784336822, subsample=0.5770904693251593 will be ignored. Current value: bagging_fraction=0.8554539784336822
# [LightGBM] [Warning] bagging_fraction is set=0.8554539784336822, subsample=0.5770904693251593 will be ignored. Current value: bagging_fraction=0.8554539784336822
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7091148620296165, subsample=0.7047972914392507 will be ignored. Current value: bagging_fraction=0.7091148620296165
# [LightGBM] [Warning] bagging_fraction is set=0.7091148620296165, subsample=0.7047972914392507 will be ignored. Current value: bagging_fraction=0.7091148620296165
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5903489714921792, subsample=0.7399257587530765 will be ignored. Current value: bagging_fraction=0.5903489714921792
# [LightGBM] [Warning] bagging_fraction is set=0.5903489714921792, subsample=0.7399257587530765 will be ignored. Current value: bagging_fraction=0.5903489714921792
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6363237022259, subsample=0.5644520788998383 will be ignored. Current value: bagging_fraction=0.6363237022259
# [LightGBM] [Warning] bagging_fraction is set=0.6363237022259, subsample=0.5644520788998383 will be ignored. Current value: bagging_fraction=0.6363237022259
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5352381000452966, subsample=0.5326212583213479 will be ignored. Current value: bagging_fraction=0.5352381000452966
# [LightGBM] [Warning] bagging_fraction is set=0.5352381000452966, subsample=0.5326212583213479 will be ignored. Current value: bagging_fraction=0.5352381000452966
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6799689774162243, subsample=0.6398127848636547 will be ignored. Current value: bagging_fraction=0.6799689774162243
# [LightGBM] [Warning] bagging_fraction is set=0.6799689774162243, subsample=0.6398127848636547 will be ignored. Current value: bagging_fraction=0.6799689774162243
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7324657704874172, subsample=0.6763786699992584 will be ignored. Current value: bagging_fraction=0.7324657704874172
# [LightGBM] [Warning] bagging_fraction is set=0.7324657704874172, subsample=0.6763786699992584 will be ignored. Current value: bagging_fraction=0.7324657704874172
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.560900758251461, subsample=0.6001872046400243 will be ignored. Current value: bagging_fraction=0.560900758251461
# [LightGBM] [Warning] bagging_fraction is set=0.560900758251461, subsample=0.6001872046400243 will be ignored. Current value: bagging_fraction=0.560900758251461
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.704779766260593, subsample=0.6929105606003291 will be ignored. Current value: bagging_fraction=0.704779766260593
# [LightGBM] [Warning] bagging_fraction is set=0.704779766260593, subsample=0.6929105606003291 will be ignored. Current value: bagging_fraction=0.704779766260593
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6311203800287633, subsample=0.6484691252984245 will be ignored. Current value: bagging_fraction=0.6311203800287633
# [LightGBM] [Warning] bagging_fraction is set=0.6311203800287633, subsample=0.6484691252984245 will be ignored. Current value: bagging_fraction=0.6311203800287633
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5718378290071473, subsample=0.5036611427559821 will be ignored. Current value: bagging_fraction=0.5718378290071473
# [LightGBM] [Warning] bagging_fraction is set=0.5718378290071473, subsample=0.5036611427559821 will be ignored. Current value: bagging_fraction=0.5718378290071473
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6023547769937252, subsample=0.5043804564964754 will be ignored. Current value: bagging_fraction=0.6023547769937252
# [LightGBM] [Warning] bagging_fraction is set=0.6023547769937252, subsample=0.5043804564964754 will be ignored. Current value: bagging_fraction=0.6023547769937252
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5771290650639784, subsample=0.7666683061526205 will be ignored. Current value: bagging_fraction=0.5771290650639784
# [LightGBM] [Warning] bagging_fraction is set=0.5771290650639784, subsample=0.7666683061526205 will be ignored. Current value: bagging_fraction=0.5771290650639784
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5300142662370386, subsample=0.5306059424062309 will be ignored. Current value: bagging_fraction=0.5300142662370386
# [LightGBM] [Warning] bagging_fraction is set=0.5300142662370386, subsample=0.5306059424062309 will be ignored. Current value: bagging_fraction=0.5300142662370386
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.56762144315351, subsample=0.5861139854907892 will be ignored. Current value: bagging_fraction=0.56762144315351
# [LightGBM] [Warning] bagging_fraction is set=0.56762144315351, subsample=0.5861139854907892 will be ignored. Current value: bagging_fraction=0.56762144315351
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5042406086804596, subsample=0.6207034480049893 will be ignored. Current value: bagging_fraction=0.5042406086804596
# [LightGBM] [Warning] bagging_fraction is set=0.5042406086804596, subsample=0.6207034480049893 will be ignored. Current value: bagging_fraction=0.5042406086804596
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.7786932205936419, subsample=0.520661550871145 will be ignored. Current value: bagging_fraction=0.7786932205936419
# [LightGBM] [Warning] bagging_fraction is set=0.7786932205936419, subsample=0.520661550871145 will be ignored. Current value: bagging_fraction=0.7786932205936419
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.5957897474224575, subsample=0.5019276146938563 will be ignored. Current value: bagging_fraction=0.5957897474224575
# [LightGBM] [Warning] bagging_fraction is set=0.5957897474224575, subsample=0.5019276146938563 will be ignored. Current value: bagging_fraction=0.5957897474224575
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.571107327964878, subsample=0.7591642867142676 will be ignored. Current value: bagging_fraction=0.571107327964878
# [LightGBM] [Warning] bagging_fraction is set=0.6270270601376835, subsample=0.5654606053651112 will be ignored. Current value: bagging_fraction=0.6270270601376835
# [LightGBM] [Warning] bagging_fraction is set=0.6270270601376835, subsample=0.5654606053651112 will be ignored. Current value: bagging_fraction=0.6270270601376835
# [LightGBM] [Warning] bagging_fraction is set=0.6270270601376835, subsample=0.5654606053651112 will be ignored. Current value: bagging_fraction=0.6270270601376835
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6270270601376835, subsample=0.5654606053651112 will be ignored. Current value: bagging_fraction=0.6270270601376835
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.816814066230276, subsample=0.7265275334639955 will be ignored. Current value: bagging_fraction=0.816814066230276
# [LightGBM] [Warning] bagging_fraction is set=0.816814066230276, subsample=0.7265275334639955 will be ignored. Current value: bagging_fraction=0.816814066230276
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.6204562947222616, subsample=0.5588258229721983 will be ignored. Current value: bagging_fraction=0.6204562947222616
# [LightGBM] [Warning] bagging_fraction is set=0.6204562947222616, subsample=0.5588258229721983 will be ignored. Current value: bagging_fraction=0.6204562947222616
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.6614653504130161, subsample=0.5832845001413896 will be ignored. Current value: bagging_fraction=0.6614653504130161
# [LightGBM] [Warning] bagging_fraction is set=0.6614653504130161, subsample=0.5832845001413896 will be ignored. Current value: bagging_fraction=0.6614653504130161
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.5249422473662213, subsample=0.8011775322101437 will be ignored. Current value: bagging_fraction=0.5249422473662213
# [LightGBM] [Warning] bagging_fraction is set=0.5249422473662213, subsample=0.8011775322101437 will be ignored. Current value: bagging_fraction=0.5249422473662213
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.7617785272387182, subsample=0.8368066367229875 will be ignored. Current value: bagging_fraction=0.7617785272387182
# [LightGBM] [Warning] bagging_fraction is set=0.7617785272387182, subsample=0.8368066367229875 will be ignored. Current value: bagging_fraction=0.7617785272387182
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.6932644177848535, subsample=0.6658151291815244 will be ignored. Current value: bagging_fraction=0.6932644177848535
# [LightGBM] [Warning] bagging_fraction is set=0.6749513989796679, subsample=0.5434383671535039 will be ignored. Current value: bagging_fraction=0.6749513989796679
# ...
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.6765490664556677, subsample=0.5570069130119862 will be ignored. Current value: bagging_fraction=0.6765490664556677
# [LightGBM] [Warning] bagging_fraction is set=0.6765490664556677, subsample=0.5570069130119862 will be ignored. Current value: bagging_fraction=0.6765490664556677
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7405705193375434, subsample=0.5000948579654381 will be ignored. Current value: bagging_fraction=0.7405705193375434
# [LightGBM] [Warning] bagging_fraction is set=0.7405705193375434, subsample=0.5000948579654381 will be ignored. Current value: bagging_fraction=0.7405705193375434
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8125765312361946, subsample=0.5415475418829918 will be ignored. Current value: bagging_fraction=0.8125765312361946
# [LightGBM] [Warning] bagging_fraction is set=0.8125765312361946, subsample=0.5415475418829918 will be ignored. Current value: bagging_fraction=0.8125765312361946
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8332208484021195, subsample=0.6024078288095316 will be ignored. Current value: bagging_fraction=0.8332208484021195
# [LightGBM] [Warning] bagging_fraction is set=0.8332208484021195, subsample=0.6024078288095316 will be ignored. Current value: bagging_fraction=0.8332208484021195
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7544961662360359, subsample=0.6108239234726945 will be ignored. Current value: bagging_fraction=0.7544961662360359
# [LightGBM] [Warning] bagging_fraction is set=0.7544961662360359, subsample=0.6108239234726945 will be ignored. Current value: bagging_fraction=0.7544961662360359
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7898032448083482, subsample=0.5113972646964507 will be ignored. Current value: bagging_fraction=0.7898032448083482
# [LightGBM] [Warning] bagging_fraction is set=0.7898032448083482, subsample=0.5113972646964507 will be ignored. Current value: bagging_fraction=0.7898032448083482
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7802274709947848, subsample=0.5710165708483012 will be ignored. Current value: bagging_fraction=0.7802274709947848
# [LightGBM] [Warning] bagging_fraction is set=0.7802274709947848, subsample=0.5710165708483012 will be ignored. Current value: bagging_fraction=0.7802274709947848
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7236073639585717, subsample=0.5937982032847142 will be ignored. Current value: bagging_fraction=0.7236073639585717
# [LightGBM] [Warning] bagging_fraction is set=0.7236073639585717, subsample=0.5937982032847142 will be ignored. Current value: bagging_fraction=0.7236073639585717
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8185549949897707, subsample=0.5505573717627078 will be ignored. Current value: bagging_fraction=0.8185549949897707
# [LightGBM] [Warning] bagging_fraction is set=0.8185549949897707, subsample=0.5505573717627078 will be ignored. Current value: bagging_fraction=0.8185549949897707
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7998089330232225, subsample=0.5300548481946487 will be ignored. Current value: bagging_fraction=0.7998089330232225
# [LightGBM] [Warning] bagging_fraction is set=0.7998089330232225, subsample=0.5300548481946487 will be ignored. Current value: bagging_fraction=0.7998089330232225
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8503952387655187, subsample=0.6219673097590356 will be ignored. Current value: bagging_fraction=0.8503952387655187
# [LightGBM] [Warning] bagging_fraction is set=0.8503952387655187, subsample=0.6219673097590356 will be ignored. Current value: bagging_fraction=0.8503952387655187
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7076995765987087, subsample=0.5193094284556132 will be ignored. Current value: bagging_fraction=0.7076995765987087
# [LightGBM] [Warning] bagging_fraction is set=0.7076995765987087, subsample=0.5193094284556132 will be ignored. Current value: bagging_fraction=0.7076995765987087
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8410631355936125, subsample=0.507787045833506 will be ignored. Current value: bagging_fraction=0.8410631355936125
# [LightGBM] [Warning] bagging_fraction is set=0.8410631355936125, subsample=0.507787045833506 will be ignored. Current value: bagging_fraction=0.8410631355936125
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7364745512724116, subsample=0.5601545932777937 will be ignored. Current value: bagging_fraction=0.7364745512724116
# [LightGBM] [Warning] bagging_fraction is set=0.7364745512724116, subsample=0.5601545932777937 will be ignored. Current value: bagging_fraction=0.7364745512724116
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8080923989047819, subsample=0.5821596118811786 will be ignored. Current value: bagging_fraction=0.8080923989047819
# [LightGBM] [Warning] bagging_fraction is set=0.8080923989047819, subsample=0.5821596118811786 will be ignored. Current value: bagging_fraction=0.8080923989047819
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7454016506406119, subsample=0.5411801305207499 will be ignored. Current value: bagging_fraction=0.7454016506406119
# [LightGBM] [Warning] bagging_fraction is set=0.7454016506406119, subsample=0.5411801305207499 will be ignored. Current value: bagging_fraction=0.7454016506406119
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7689138694276899, subsample=0.5689291168141509 will be ignored. Current value: bagging_fraction=0.7689138694276899
# [LightGBM] [Warning] bagging_fraction is set=0.7689138694276899, subsample=0.5689291168141509 will be ignored. Current value: bagging_fraction=0.7689138694276899
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.8247192372846873, subsample=0.5344343947389362 will be ignored. Current value: bagging_fraction=0.8247192372846873
# [LightGBM] [Warning] bagging_fraction is set=0.8247192372846873, subsample=0.5344343947389362 will be ignored. Current value: bagging_fraction=0.8247192372846873
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.6976856895601923, subsample=0.6322757455742045 will be ignored. Current value: bagging_fraction=0.6976856895601923
# [LightGBM] [Warning] bagging_fraction is set=0.6976856895601923, subsample=0.6322757455742045 will be ignored. Current value: bagging_fraction=0.6976856895601923
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
# [LightGBM] [Warning] bagging_fraction is set=0.5826257820828384, subsample=0.5343866057039434 will be ignored. Current value: bagging_fraction=0.5826257820828384
# [LightGBM] [Warning] bagging_fraction is set=0.7849371457632067, subsample=0.5503348243931592 will be ignored. Current value: bagging_fraction=0.7849371457632067
# [LightGBM] [Warning] bagging_fraction is set=0.7849371457632067, subsample=0.5503348243931592 will be ignored. Current value: bagging_fraction=0.7849371457632067
# [LightGBM] [Info] Total Bins 9845
# [LightGBM] [Info] Number of data points in the train set: 1826086, number of used features: 44
# [LightGBM] [Info] Start training from score 0.000367
#  12%|█▏        | 363/3000 [1:58:41<14:22:13, 19.62s/trial, best loss: -0.4699139372309995]
# best params: {'bagging_fraction': 0.8129300896075456, 'feature_fraction': 0.8997963192996467, 'lambda_l1': 0.48667613936866305, 'lambda_l2': 0.16960014569414728, 'learning_rate': 0.09998532471948109, 'max_depth': 0, 'min_data_in_leaf': 185, 'num_leaves': 47, 'subsample': 0.5366895744256853}

# %%
# the best sharpe-ration on validation set is 0.47
params_best
# Out:
# {'bagging_fraction': 0.8129300896075456,
#  'feature_fraction': 0.8997963192996467,
#  'lambda_l1': 0.48667613936866305,
#  'lambda_l2': 0.16960014569414728,
#  'learning_rate': 0.09998532471948109,
#  'max_depth': 0,
#  'min_data_in_leaf': 185,
#  'num_leaves': 47,
#  'subsample': 0.5366895744256853}

# %%
object(params_best)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.5878680772191447, subsample=0.8312406282187306 will be ignored. Current value: bagging_fraction=0.5878680772191447
# [LightGBM] [Warning] bagging_fraction is set=0.6695906917000655, subsample=0.7816225127761227 will be ignored. Current value: bagging_fraction=0.6695906917000655
# [LightGBM] [Warning] bagging_fraction is set=0.6695906917000655, subsample=0.7816225127761227 will be ignored. Current value: bagging_fraction=0.6695906917000655
# [LightGBM] [Info] Total Bins 8817
# [LightGBM] [Info] Number of data points in the train set: 2370539, number of used features: 39
# [LightGBM] [Info] Start training from score 0.000440
# -0.05964972372031924

# %% [markdown]
# # Final sumission on kaggle

# %% [markdown]
# ## imports and seeds

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ('2017-01-04', '2022-06-24')

# %%
import math
import os
from scipy import stats
import lightgbm as lgb
import jpx_tokyo_market_prediction
import random

import warnings

warnings.filterwarnings('ignore')

def seed_everything(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

SEED=42
seed_everything(SEED)

# %% [markdown]
# ## data preprocessing

# %%
def proprocessing_financials(financials):
    def finance_check(x):
        if "_Consolidated_" in x:
            return 1
        else:
            return 0
    
    
    financials["TypeOfDocument"]=financials["TypeOfDocument"].astype(str)
    financials["OperatingProfit"]=financials["OperatingProfit"].apply(convert_float)
    financials["NetSales"]=financials["NetSales"].apply(convert_float)
    financials['EquityToAssetRatio']= financials['EquityToAssetRatio'].apply(convert_float)
    
    
    financials["check"]=financials["TypeOfDocument"].apply(lambda x: 1 if "_Consolidated_" in x else 0)
    financials=financials[financials["check"]==1]
    financials=financials.fillna(0)
    financials=financials.replace([np.inf, -np.inf], 0)
    financials["OperationMargin"] = financials["OperatingProfit"]/financials["NetSales"]
    financials=financials.replace([np.inf, -np.inf], 0)
    financials["Statement_Date"]=1
   
    
    return financials[['Date', 'SecuritiesCode','OperationMargin','EquityToAssetRatio','Statement_Date']]

# %%
def convert_float(x):
    try:
        return float(x)
    except:
        return None
    
def seq_count(row):
    if pd.isna(row["close4"]):
        return None
    elif row["4_day_compare"]==0:
        return row["count"]*(-1)
    else:
        return row["count"]
    
def convert_str(x):
    try:
        return str(x)
    except:
        return None

# %%
def real_close(prices):
    prices=prices.sort_values("Date", ascending=False)
    prices["CumAdjustFactor"] = prices["AdjustmentFactor"].cumprod()
    prices["real_close"] = prices["CumAdjustFactor"]*prices["Close"]
    prices= prices.sort_values("Date")
    prices[prices["real_close"]==0]["real_close"] = np.nan
    prices["real_close"] = prices["real_close"].ffill()
    return prices

# %%
def price_preprocess(prices):
    prices.fillna(0)
    prices.replace([np.inf, -np.inf], 0)
    prices = prices.sort_values(["SecuritiesCode", "Date"])
    
    prices['volume_ratio']=prices["Volume"]/prices["IssuedShares"]
    prices['daily_price_change']=(prices["High"]-prices["Low"])/prices["Open"]
    prices["price/volume"]=prices["daily_price_change"]/prices["volume_ratio"]
    
    df=pd.DataFrame()
    stock_code_list=prices.SecuritiesCode.unique().tolist()
    


    
    for codei in stock_code_list:

        stocki_df=prices[prices["SecuritiesCode"]==codei]
        
     
        #daily price change
        stocki_df["daily_price_change1"]=stocki_df["daily_price_change"].shift(1)
        stocki_df["daily_price_change2"]=stocki_df["daily_price_change"].shift(2)
        stocki_df["daily_price_change3"]=stocki_df["daily_price_change"].shift(3)
        stocki_df["daily_price_change4"]=stocki_df["daily_price_change"].shift(4)
        
        
        #
        stocki_df["close4"]=stocki_df["real_close"].shift(4)
        stocki_df["4_day_compare"]=(stocki_df["real_close"]>=stocki_df["close4"]).astype(int)
        groups = (stocki_df['4_day_compare'] != stocki_df['4_day_compare'].shift()).cumsum()
        stocki_df["count"]=stocki_df.groupby(["4_day_compare",groups]).cumcount()+1
        stocki_df["seq_count"]=stocki_df.apply(seq_count,axis=1)

        #brein band
        stocki_df["brein_up"] = stocki_df['real_close'].rolling(window=20).mean() +2*stocki_df['real_close'].rolling(window=20).std()

        stocki_df["brein_down"] = stocki_df['real_close'].rolling(window=20).mean() -2*stocki_df['real_close'].rolling(window=20).std()
        stocki_df["brein_width"] = stocki_df['real_close'].rolling(window=20).mean() +4*stocki_df['real_close'].rolling(window=20).std()
        #stocki_df["distance_brein_up"] = np.abs(stocki_df['real_close'] -stocki_df["brein_up"]) / stocki_df["brein_width"]
        #stocki_df["distance_brein_down"] = np.abs(stocki_df['real_close'] -stocki_df["brein_down"]) / stocki_df["brein_width"]


        # RSI -14

        stocki_df["real_close_diff1"]=stocki_df["real_close"].diff(1)
        stocki_df["gain"]=stocki_df["real_close_diff1"].clip(lower=0)
        stocki_df["loss"]=stocki_df["real_close_diff1"].clip(upper=0).abs()
        stocki_df["avg_gain"]=stocki_df["gain"].rolling(window=14).mean()
        stocki_df["avg_loss"]=stocki_df["loss"].rolling(window=14).mean()
        #stocki_df["RS"]=stocki_df["avg_gain"]/stocki_df["avg_loss"]
        #stocki_df["RSI"]= 100-(100/(1+stocki_df["RS"]))
       



        

        #targets ARs

        stocki_df["future_close1"]=stocki_df["real_close"].shift(-1)
        stocki_df["future_close2"]=stocki_df["real_close"].shift(-2)
        stocki_df["calculated_target"]=(stocki_df["future_close2"] - stocki_df["future_close1"])/stocki_df["future_close1"]
        stocki_df["target_3"]=stocki_df["calculated_target"].shift(3)
        stocki_df["target_4"]=stocki_df["calculated_target"].shift(4)
        stocki_df["target_5"]=stocki_df["calculated_target"].shift(5)

     
        
        #price moving average ratio
        stocki_df['5_day_price_MA_ratio']  = stocki_df['real_close']/stocki_df['real_close'].rolling(window=5).mean()
        stocki_df['10_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=10).mean()
        stocki_df['20_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=20).mean()
        stocki_df['40_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=40).mean()
        stocki_df['60_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=60).mean()
        stocki_df['120_day_price_MA_ratio'] = stocki_df['real_close']/stocki_df['real_close'].rolling(window=120).mean()
        
        
        # volatilities
        #stocki_df['5_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=5).std()
        #stocki_df['10_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=10).std()
        stocki_df['20_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=20).std()
        stocki_df['40_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=40).std()
        stocki_df['60_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=60).std()
        stocki_df['120_day_price_volatility'] = np.log(stocki_df['real_close']).diff().rolling(window=120).std()
        
        # return 
        
        stocki_df["5_day_return"]=stocki_df["real_close"].pct_change(5)
        stocki_df["10_day_return"]=stocki_df["real_close"].pct_change(10)
        stocki_df["20_day_return"]=stocki_df["real_close"].pct_change(20)
        stocki_df["40_day_return"]=stocki_df["real_close"].pct_change(40)
        stocki_df["60_day_return"]=stocki_df["real_close"].pct_change(60)
        stocki_df["120_day_return"]=stocki_df["real_close"].pct_change(120)
     
       # volume moving average
        
        
        stocki_df["5_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=5).mean()
        stocki_df["10_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=10).mean()
        stocki_df["20_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=20).mean()
        stocki_df["40_day_volume_ratio_MA"]=stocki_df["volume_ratio"].rolling(window=40).mean()
      
       # volumn volatilities
        
        #stocki_df["5_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=5).std()
        #stocki_df["10_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=10).std()
        stocki_df["20_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=20).std()
        stocki_df["40_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=40).std()
        stocki_df["60_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=60).std()
        stocki_df["120_day_volume_ratio_std"]=stocki_df["volume_ratio"].rolling(window=120).std()

       #
        
        

        df=pd.concat([df,stocki_df]) 

    df["distance_brein_up"] = round(np.abs(df['real_close'] -df["brein_up"]) / df["brein_width"],2)
    df["distance_brein_down"] = round(np.abs(df['real_close'] - df["brein_down"]) / df["brein_width"],2)

    df["RS"]=round(df["avg_gain"]/df["avg_loss"],2)
    df["RSI"]= round(100-(100/(1+df["RS"])),0)

        
    return df

# %%
def train_data_preprocess(stock_prices,stock_info,financials):
    stock_info=stock_info_preprocessing(stock_info)
    finance=proprocessing_financials(financials)
    prices=stock_prices.merge(stock_info,left_on=["SecuritiesCode"],right_on=["SecuritiesCode"],how="left")
    prices = prices.sort_values(["SecuritiesCode", "Date"])
    prices = prices.groupby("SecuritiesCode").apply(real_close).reset_index(drop=True)
    prices=price_preprocess(prices)
    prices=prices.merge(finance,left_on=["Date","SecuritiesCode"],right_on=["Date","SecuritiesCode"],how="left")
    prices['OperationMargin']=prices['OperationMargin'].fillna(method="ffill")
    prices['EquityToAssetRatio']=prices['EquityToAssetRatio'].fillna(method="ffill")
    prices["Volume"]=prices["Volume"].astype(float)
    prices["33SectorCode"]= prices["33SectorCode"].astype(int)
    prices["SupervisionFlag"]= prices["SupervisionFlag"].astype(int)
    
    return prices

# %%
stock_prices=pd.concat([stock_prices,stock_prices2])
financials=pd.concat([financials,financials2])

# %%
data=train_data_preprocess(stock_prices,stock_info,financials)

# %% [markdown]
# ## modeling training

# %%
# customized loss functions
def l2_loss(y, data):
    t = data.get_label()
    grad = y - t 
    hess = np.ones_like(y)
    return grad, hess

def l2_eval(y, data):
    t = data.get_label()
    loss = (y - t) ** 2 
    return 'l2', loss.mean(), False  

def feval_pearsonr(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'pearsonr', stats.pearsonr(y_true, y_pred)[0], True

# %%
#train validation split
code_list=data.SecuritiesCode.unique().tolist()
train_list=random.sample(code_list,1400)
validation_list=np.setxor1d(code_list,train_list)

# %%
features=[ 'ExpectedDividend', 'Volume',"daily_price_change","daily_price_change1",
          "daily_price_change2","daily_price_change3","daily_price_change4",
          '33SectorCode','OperationMargin','EquityToAssetRatio','volume_ratio',"distance_brein_up","distance_brein_down","RSI",
          'seq_count','target_3','target_4','target_5',"SupervisionFlag",
          '5_day_price_MA_ratio',
          '10_day_price_MA_ratio', '20_day_price_MA_ratio',
          '40_day_price_MA_ratio', '60_day_price_MA_ratio',
          '120_day_price_MA_ratio',     '20_day_price_volatility','40_day_price_volatility','60_day_price_volatility', '120_day_price_volatility','5_day_return', '10_day_return',
        '20_day_return', '40_day_return', '60_day_return', '120_day_return',
        "5_day_volume_ratio_MA","10_day_volume_ratio_MA","20_day_volume_ratio_MA","40_day_volume_ratio_MA",
        '20_day_volume_ratio_std','40_day_volume_ratio_std',
        '60_day_volume_ratio_std', '120_day_volume_ratio_std',"price/volume"
               ]

# %%
tr_dataset = lgb.Dataset(data[data['SecuritiesCode'].isin(train_list)][features],data[data['SecuritiesCode'].isin(train_list)]["Target"],feature_name = features,categorical_feature=['33SectorCode','SupervisionFlag'] )
vl_dataset = lgb.Dataset(data[data['SecuritiesCode'].isin(validation_list)][features], data[data['SecuritiesCode'].isin(validation_list)]["Target"],feature_name = features,categorical_feature=['33SectorCode','SupervisionFlag'])


params_lgb={'metric':'None',
'objective': 'regression',
'force_col_wise':True,
'bagging_fraction': 0.813,
 'feature_fraction': 0.90,
 'lambda_l1': 0.487,
 'lambda_l2': 0.170,
 'learning_rate': 0.1,
 #'max_depth': 6,
 'min_data_in_leaf': 185,
 'num_leaves': 47,
 'subsample': 0.537}


model = lgb.train(  params = params_lgb, 
                train_set = tr_dataset, 
                valid_sets = [tr_dataset, vl_dataset],                
                num_boost_round = 5000, 
                feval=feval_pearsonr,
                
                callbacks=[ lgb.early_stopping(stopping_rounds=300 , verbose=True), lgb.log_evaluation(period=100)]
               )

# %% [markdown]
# ## submission

# %%
sample_submission = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/example_test_files/sample_submission.csv")

env = jpx_tokyo_market_prediction.make_env()   # initialize the environment
iter_test = env.iter_test()    # an iterator which loops over the test files

# %%
stock_prices_all= stock_prices.copy()
financials_all=financials.copy()

# %%
counter=0

for (prices, options, financials, trades, secondary_prices, sample_prediction) in iter_test: 
    
    current_date=prices.Date.min()
    sample_prediction_date=sample_prediction["Date"].iloc[0]
    
    print(f"current_date: {current_date}, sample_prediction_date: {sample_prediction_date}")
    
    if counter==0:
        stock_prices_all=stock_prices_all[stock_prices_all["Date"]<current_date]
        financials_all=financials_all[financials_all["Date"]<current_date]
    
        
    stock_prices_all = pd.concat([stock_prices_all,prices])
    financials_all= pd.concat([financials_all, financials])
    
    data=train_data_preprocess(stock_prices_all.copy(),stock_info.copy(),financials_all.copy())
    data=data[data["Date"]==current_date]
    
    data['pred_target'] = model.predict(data[features])
    
    data["Rank"]=data["pred_target"].rank(ascending=False, method="first") - 1
    
    rank_map= data.set_index('SecuritiesCode')['Rank'].to_dict()
    sample_prediction['Rank'] = sample_prediction['SecuritiesCode'].map(rank_map)
    sample_prediction["Rank"] = sample_prediction["Rank"].astype(int)
    
    assert sample_prediction["Rank"].notna().all()
    assert sample_prediction["Rank"].min() == 0
    assert sample_prediction["Rank"].max() == len(sample_prediction["Rank"]) - 1

    # register your predictions
    env.predict(sample_prediction)
    counter+=1

# %%
! head submission.csv
